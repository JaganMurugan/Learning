# %% [markdown]
# <a href="https://colab.research.google.com/github/JaganMurugan/Learning/blob/main/Torch_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
import torch

# %%
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

rows, cols = 3, 3

# %%
figure = plt.figure(figsize=(8, 8))
for i in range(1, rows*cols + 1):
  index = torch.randint(len(training_data), size=(1,)).item()
  img, label = training_data[index]
  figure.add_subplot(rows, cols, i)
  plt.title(labels_map[label])
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="grey")

plt.show()

# %%
import pandas as pd
import numpy as np

# %%
dates = pd.date_range("20250726", periods=6)
dates
# Out:
# DatetimeIndex(['2025-07-26', '2025-07-27', '2025-07-28', '2025-07-29',
#                '2025-07-30', '2025-07-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2025-07-26  0.133154 -1.440705  0.887715  0.614015
# 2025-07-27  0.875091 -0.541200 -0.721368 -1.084959
# 2025-07-28 -0.684352 -0.915786  0.790696 -0.563741
# 2025-07-29  0.235958 -0.009714 -0.353924 -1.007510
# 2025-07-30 -1.355920  0.898452 -0.341683 -0.627940
# 2025-07-31  0.661196 -0.641157 -0.115737 -0.744153

# %%
np.array([3])
# Out:
# array([3])

# %%
np.array([3]).shape
# Out:
# (1,)

# %%
np.array([3]* 4)
# Out:
# array([3, 3, 3, 3])

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20250726"),
    "C": pd.Series(1, index=list(range(4)), dtype="float32"),
    "D": np.array([3] * 4, dtype="float32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo"
})
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2025-07-26  1.0  3.0   test  foo
# 1  1.0 2025-07-26  1.0  3.0  train  foo
# 2  1.0 2025-07-26  1.0  3.0   test  foo
# 3  1.0 2025-07-26  1.0  3.0  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D          float32
# E         category
# F           object
# dtype: object

# %%
df2.head()
# Out:
#      A          B    C    D      E    F
# 0  1.0 2025-07-26  1.0  3.0   test  foo
# 1  1.0 2025-07-26  1.0  3.0  train  foo
# 2  1.0 2025-07-26  1.0  3.0   test  foo
# 3  1.0 2025-07-26  1.0  3.0  train  foo

# %%
df2.tail()
# Out:
#      A          B    C    D      E    F
# 0  1.0 2025-07-26  1.0  3.0   test  foo
# 1  1.0 2025-07-26  1.0  3.0  train  foo
# 2  1.0 2025-07-26  1.0  3.0   test  foo
# 3  1.0 2025-07-26  1.0  3.0  train  foo

# %%
df2.tail(2)
# Out:
#      A          B    C    D      E    F
# 2  1.0 2025-07-26  1.0  3.0   test  foo
# 3  1.0 2025-07-26  1.0  3.0  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2025-07-26 00:00:00'), 1.0, 3.0, 'test', 'foo'],
#        [1.0, Timestamp('2025-07-26 00:00:00'), 1.0, 3.0, 'train', 'foo'],
#        [1.0, Timestamp('2025-07-26 00:00:00'), 1.0, 3.0, 'test', 'foo'],
#        [1.0, Timestamp('2025-07-26 00:00:00'), 1.0, 3.0, 'train', 'foo']],
#       dtype=object)

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2025-07-26 00:00:00  1.0  3.0
# min    1.0  2025-07-26 00:00:00  1.0  3.0
# 25%    1.0  2025-07-26 00:00:00  1.0  3.0
# 50%    1.0  2025-07-26 00:00:00  1.0  3.0
# 75%    1.0  2025-07-26 00:00:00  1.0  3.0
# max    1.0  2025-07-26 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d25f20e4-1fdb-4c60-861b-8772030c308e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d25f20e4-1fdb-4c60-861b-8772030c308e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
list(uploaded.keys())
# Out:
# ['Finance_Csv.csv']

# %%
df = pd.read_csv("Finance_Csv.csv")

# %%
df.describe()
# Out:
#         Sep-20   ? 2,000.00
# count      229          231
# unique     124          153
# top     11-Jan  ? 50,000.00
# freq         7           12

# %%
df.head()
# Out:
#    Sep-20    ? 2,000.00
# 0  Sep-21   ? 50,000.00
# 1  Sep-26  ? 550,000.00
# 2  Sep-30  ? 100,000.00
# 3   4-Oct  ? 550,000.00
# 4  20-Oct  ? 250,000.00

# %%
df.columns
# Out:
# Index(['Sep-20', '? 2,000.00'], dtype='object')

# %%
df.dtypes
# Out:
# Sep-20        object
# ? 2,000.00    object
# dtype: object

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d0cc63c-4ffb-4c9d-8be8-819e1efa5ab4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d0cc63c-4ffb-4c9d-8be8-819e1efa5ab4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Finance_Csv (1).csv")

# %%
df.head()
# Out:
#    20-Sep    2,000.00
# 0  21-Sep   50,000.00
# 1  26-Sep  550,000.00
# 2  30-Sep  100,000.00
# 3   4-Oct  550,000.00
# 4  20-Oct  250,000.00

# %%
df.describe()
# Out:
#         20-Sep   2,000.00
# count      229        231
# unique     124        153
# top     11-Jan  50,000.00
# freq         7         12

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31be299c-27fa-4042-9513-7a18081f270b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31be299c-27fa-4042-9513-7a18081f270b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Finance_Csv (2).csv")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Date      Amount
# 0    20-Sep    2,000.00
# 1    21-Sep   50,000.00
# 2    26-Sep  550,000.00
# 3    30-Sep  100,000.00
# 4     4-Oct  550,000.00
# ..      ...         ...
# 247   6-Jul    9,500.00
# 248   7-Jul         890
# 249  11-Jul         500
# 250  11-Jul   10,000.00
# 251  12-Jul   26,200.00
#
# [252 rows x 2 columns]>

# %%
df.describe()
# Out:
#           Date     Amount
# count      230        232
# unique     125        153
# top     11-Jan  50,000.00
# freq         7         12

# %%
df.dtypes
# Out:
# Date      object
# Amount    object
# dtype: object

# %%
import os

# %%
if os.path.exists("Finance_Csv.csv"):
  os.remove("Finance_Csv.csv")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1c11ba87-d9dd-4a8a-982c-75bf7e3cfec9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c11ba87-d9dd-4a8a-982c-75bf7e3cfec9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from torch.utils.data import Dataset
import pandas as pd
import torchvision
from torchvision.io import decode_image

class CustomDataset(Dataset):
  def __init__(self, annotations_file, img_dir, transforms=None, target_transforms=None):
    self.img_labels = pd.read_csv(annotations_file)
    self.img_dir = img_dir
    self.transforms = transforms
    self.target_transforms = target_transforms

  def __len__(self):
    return len(list(self.img_labels.iloc[0]))

  def __get_item__(self, idx):
    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = decode_image(img_path)
    label = self.img_labels.iloc[idx]
    if self.transform:
      image = self.transform(image)
    if self.target_transform:
      label = self.target_transform(label)
    return image, label

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape : {train_features.shape()}")
print(f"Labels batch size : {train_labels.shape()}")
training_image = train_features[0].squeeze
plt.imshow(training_image, cmap="grey")
plt.show
print(f"Label: {train_labels[0]}")
